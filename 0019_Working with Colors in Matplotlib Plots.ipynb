# %%
# %matplotlib inline

# %% [markdown]
# # Day 0019 - Working with Colors in Matplotlib Plots
# # - 1000 days of Python

# %% [markdown]
# # Setup working directory

# %%
pwd
# Out:
# 'D:\\desktop\\Python\\1000 days of python'

# %%
pwd
# Out:
# 'D:\\desktop\\Python\\1000 days of python'

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Generate Random Colors in Matplotlib Plots

# %% [markdown]
# ## 1.2 Generate Random Color for Line Plot

# %%
#define data
x = [1, 2, 3, 4, 5]
y = [7, 12, 15, 19, 25]

#define random color
col = (np.random.random(), np.random.random(), np.random.random())

#create line plot with random color
plt.plot(x, y, c=col);
plt.show()

# %%
#Run second time
col = (np.random.random(), np.random.random(), np.random.random())
plt.plot(x, y, c=col);
plt.show()

# %% [markdown]
# ## Generate Random Colors for Scatterplot

# %%
import matplotlib.pyplot as plt
import numpy as np

#define data
x = [1, 2, 3, 4, 5]
y = [7, 12, 15, 19, 25]

#create scatterplot with random colors for each point
plt.scatter(x, y, c=np.random.rand(len(x),3))

# %%
#Run second time
plt.scatter(x, y, c=np.random.rand(len(x),3))

# %% [markdown]
# # 2. Background Color in Matplotlib

# %% [markdown]
# ## 2.1 Set Background Color Using Color Name

# %%
import matplotlib.pyplot as plt

#define plot figure and axis
fig, ax = plt.subplots()

#define two arrays for plotting
A = [3, 5, 5, 6, 7, 8]
B = [12, 14, 17, 20, 22, 27]

#create scatterplot and specify background color to be pink
ax.scatter(A, B)
ax.set_facecolor('pink')

#display scatterplot
plt.show()

# %% [markdown]
# ## 2.2 Set Background Color Using Hex Color Code

# %%
import matplotlib.pyplot as plt

#define plot figure and axis
fig, ax = plt.subplots()

#define two arrays for plotting
A = [3, 5, 5, 6, 7, 8]
B = [12, 14, 17, 20, 22, 27]

#create scatterplot and specify background color to be pink
ax.scatter(A, B)
ax.set_facecolor('#33FFA2')

#display scatterplot
plt.show()

# %% [markdown]
# ## 2.3 Set Background Color of Specific Subplot

# %%
import matplotlib.pyplot as plt

#define subplots
fig, ax = plt.subplots(2, 2)
fig.tight_layout()

#define background color to use for each subplot
ax[0,0].set_facecolor('blue')
ax[0,1].set_facecolor('pink')
ax[1,0].set_facecolor('green')
ax[1,1].set_facecolor('red')

#display subplots
plt.show()

# %% [markdown]
# # 3. Color a scatter plot by values using Matplotlib

# %% [markdown]
# ## 3.1 Color Scatterplot Points by Value

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='viridis')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='hsv')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='ocean')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='jet')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='rainbow')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='gist_rainbow')

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': [3, 4, 4, 5, 7, 8, 8, 9]})
import matplotlib.pyplot as plt

#create scatterplot
plt.scatter(df.x, df.y, s=200, c=df.z, cmap='brg')

# %% [markdown]
# ## 3.2 Color Scatterplot Points by Category

# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'x': [25, 12, 15, 14, 19, 23, 25, 29],
                   'y': [5, 7, 7, 9, 12, 9, 9, 4],
                   'z': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C']})
import matplotlib.pyplot as plt

groups = df.groupby('z')
for name, group in groups:
    plt.plot(group.x, group.y, marker='o', linestyle='', markersize=12, label=name)

plt.legend()

# %% [markdown]
# # References
# 1. https://www.statology.org/matplotlib-random-color/
# 2. https://www.statology.org/matplotlib-background-color/
# 3. https://www.statology.org/matplotlib-scatterplot-color-by-value/
