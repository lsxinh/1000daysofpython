# %%
#Reference: Python for Microscopists by DigitalSreeni - The best channel in my opinion.
# https://www.youtube.com/watch?v=CTOURPZftuU

# %%
# %matplotlib inline

# %% [markdown]
# # 0004_Basic Image Processing Using Scikit-image - 1000 days of Python

# %%
"""
# Let us start by looking at basic image transformation tasks like
#resize and rescale.
#Then let's look at a few ways to do edge detection.
#And then sharpening using deconvolution method and finally
#Then let's take a real life scenario like scratch assay analysis.

"""

# %%
import matplotlib.pyplot as plt
from skimage import io, color
from skimage.transform import rescale, resize, downscale_local_mean
from matplotlib.pyplot import figure

# %%
pwd
# Out:
# 'D:\\desktop\\Python\\1000 days of python'

# %%
cd reference\digitalSreeni\python_for_microscopists-master
# Out:
# D:\desktop\Python\1000 days of python\reference\digitalSreeni\python_for_microscopists-master

# %%
pwd
# Out:
# 'D:\\desktop\\Python\\1000 days of python\\reference\\digitalSreeni\\python_for_microscopists-master'

# %% [markdown]
# ## Rescale

# %%
img = io.imread("images/test_image.jpg", as_gray=True)

# %%
#Rescale, resize image by a given factor. While rescaling image
#gaussian smoothing can performed to avoid anti aliasing artifacts.
img_rescaled1 = rescale(img, 1.0 / 4.0, anti_aliasing=False)  #Check rescales image size in variable explorer
img_rescaled2 = rescale(img, 1.0 / 4.0, anti_aliasing=True)
figure(figsize=(12,4), dpi=80)

plt.subplot(1,3,1)
plt.imshow(img, cmap="Greys")
plt.title('Original image \n cmap="Greys"')
plt.colorbar()

plt.subplot(1,3,2)
plt.imshow(img_rescaled1, cmap="Greys")
plt.title('Rescale image \n anti_aliasing=False')

plt.subplot(1,3,3)
plt.imshow(img_rescaled2, cmap="Greys")
plt.title('Rescale image \n anti_aliasing=True')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Resize

# %%
#Resize, resize image to given dimensions (shape)
img_ressize1 = resize(img, (200, 200), anti_aliasing=False)  #Check rescales image size in variable explorer
img_ressize2 = resize(img, (200, 200), anti_aliasing=True)
figure(figsize=(12,4), dpi=80)

plt.subplot(1,3,1)
plt.imshow(img)
plt.title('Original image \n cmap="None"')
plt.colorbar()

plt.subplot(1,3,2)
plt.imshow(img_ressize1)
plt.title('Resize image \n anti_aliasing=False')

plt.subplot(1,3,3)
plt.imshow(img_ressize2)
plt.title('Resize image \n anti_aliasing=True')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Downscale

# %%
#Downscale, downsample using local mean of elements of each block defined by user
img_downscaled = downscale_local_mean(img, (4, 3))

figure(figsize=(12,4), dpi=80)

plt.subplot(1,3,1)
plt.imshow(img)
plt.title('Original image')


plt.subplot(1,3,2)
plt.imshow(img_downscaled)
plt.title('downscale_local_mean')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Edge detection

# %%
import matplotlib.pyplot as plt
from skimage import io
from skimage.filters import roberts, sobel, scharr, prewitt

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(8, 8))
ax = axes.ravel()

ax[0].imshow(img, cmap=plt.cm.gray)
ax[0].set_title('Original image')

edge_roberts = roberts(img)
ax[1].imshow(edge_roberts, cmap=plt.cm.gray)
ax[1].set_title('Roberts Edge Detection')

edge_sobel = sobel(img)
ax[2].imshow(edge_sobel, cmap=plt.cm.gray)
ax[2].set_title('Sobel')

edge_scharr = scharr(img)
ax[3].imshow(edge_scharr, cmap=plt.cm.gray)
ax[3].set_title('Scharr')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %%
#Another edge filter is Canny. This is not just a single operation
#It does noise reduction, gradient calculation, and edge tracking among other things. 
#Canny creates a binary file, true or false pixels. 
from skimage import feature


# plt.imshow(edge_canny)

fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True,
                         figsize=(12, 8))
ax = axes.ravel()

ax[0].imshow(img, cmap=plt.cm.gray)
ax[0].set_title('Original image')

edge_canny = feature.canny(img, sigma=1)
ax[1].imshow(edge_canny, cmap=plt.cm.gray)
ax[1].set_title('edge_canny sigma=1')

edge_canny = feature.canny(img, sigma=3)
ax[2].imshow(edge_canny, cmap=plt.cm.gray)
ax[2].set_title('edge_canny sigma=3')

edge_canny = feature.canny(img, sigma=4)
ax[3].imshow(edge_canny, cmap=plt.cm.gray)
ax[3].set_title('edge_canny sigma=4')

for a in ax:
    a.axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True,
                         figsize=(12, 8))
ax = axes.ravel()

img = io.imread("images/test_image_cropped.jpg", as_gray=True)  #Convert to grey scale
print(img.shape)
ax[0].imshow(img, cmap=plt.cm.gray, interpolation='nearest')
ax[0].set_title('Original image')

edge_roberts = roberts(img)
edge_sobel = sobel(img)
edge_scharr = scharr(img)
edge_prewitt = prewitt(img)
ax[1].imshow(edge_roberts, cmap=plt.cm.gray, interpolation='nearest')
ax[1].set_title('edge_roberts')
ax[2].imshow(edge_sobel, cmap=plt.cm.gray, interpolation='nearest')
ax[2].set_title('edge_sobel')
ax[3].imshow(edge_scharr, cmap=plt.cm.gray, interpolation='nearest')
ax[3].set_title('edge_scharr')
ax[4].imshow(edge_prewitt, cmap=plt.cm.gray, interpolation='nearest')
ax[4].set_title('edge_prewitt')
ax[5].imshow(edge_canny, cmap=plt.cm.gray, interpolation='nearest')
ax[5].set_title('edge_canny sigma=4')

plt.tight_layout()
plt.show()
# Out:
# (231, 263)

# %% [markdown]
# ## Image deconvolution

# %%
#Uses deconvolution to sharpen images. 

import matplotlib.pyplot as plt
from skimage import io, color, restoration, img_as_float

img = img_as_float(io.imread("images/BSE_Google_blurred.jpg"))
print(img.shape)
plt.imshow(img);
plt.title('Original Image')
plt.show()
#PSF
import scipy.stats as st
import numpy as np

psf = np.ones((3, 3)) / 9  #point spread function to be used for deconvolution.
# print(psf)

deconvolved, _ = restoration.unsupervised_wiener(img, psf)
plt.imshow(deconvolved);
plt.title(f'deconvolved Image \n psf = np.ones((3, 3)) / 9 \n{psf}')
plt.show()

#The following page was used as reference to generate the kernel
#https://homepages.inf.ed.ac.uk/rbf/HIPR2/gsmooth.htm

def gkern(kernlen=21, nsig=2):    #Returns a 2D Gaussian kernel.

    lim = kernlen//2 + (kernlen % 2)/2
    x = np.linspace(-lim, lim, kernlen+1)
    kern1d = np.diff(st.norm.cdf(x))
    kern2d = np.outer(kern1d, kern1d)
    return kern2d/kern2d.sum()

psf = gkern(5,3)   #Kernel length and sigma
# print(psf)

deconvolved, _ = restoration.unsupervised_wiener(img, psf)
plt.imshow(deconvolved);
plt.title(f'deconvolved Image \n 2D Gaussian kernel \n{psf}')
plt.show()
plt.imsave("images/deconvolved.jpg", deconvolved, cmap='gray')
# Out:
# (714, 901)

# %% [markdown]
# ## Real world Example

# %%
#########################################
#Let's find a way to calculate the area of scratch in would healing assay
#Entropy filter
#e.g. scratch assay where you have rough region with cells and flat region of scratch.
#entropy filter can be used to separate these regions
import matplotlib.pyplot as plt
from skimage import io, color, restoration, img_as_float
img = io.imread("images/scratch.jpg")
print(img.shape)
from skimage.filters import try_all_threshold
from skimage.filters.rank import entropy
from skimage.morphology import disk

entropy_img = entropy(img, disk(3))

fig, ax = try_all_threshold(entropy_img, figsize=(12, 8), verbose=False)
plt.show()
# Out:
# (289, 400)

# %%
#Checkout this page for entropy and other examples
#https://scikit-image.org/docs/stable/auto_examples/

plt.imshow(entropy_img, cmap=plt.cm.gray)
plt.title('Original Image, gray scale')
plt.show()
#Once you have the entropy iamge you can apply a threshold to segment the image
#If you're not sure which threshold works fine, skimage has a way for you to check all 

#Now let us test Otsu segmentation. 
from skimage.filters import threshold_otsu
thresh = threshold_otsu(entropy_img)   #Just gives us a threshold value. Check in variable explorer.
binary= entropy_img <=thresh  #let us generate a binary image by separating pixels below and above threshold value.
plt.imshow(binary, cmap=plt.cm.gray)

#We can do the same exercise on all images in the time series and plot the area to understand cell proliferation over time
plt.title('Otsu segmentation')
plt.show()

#Print toal number of true (white) pixels
total_no_of_white_pixel = (np.sum(binary == 1)*100)/(np.sum(binary == 0) + np.sum(binary == 1))
print("The percent white region is: ", round(total_no_of_white_pixel,2) )
# Out:
# The percent white region is:  28.92

# %%
###################################################################

# HOG
import matplotlib.pyplot as plt
from skimage import io, color, restoration, img_as_float
from skimage.feature import hog
from skimage import data, exposure

img = io.imread("images/Neuron.jpg", as_gray=False)
print(img.shape)

fd, hog_image = hog(img, orientations=12, pixels_per_cell=(8, 8), cells_per_block=(2, 2), 
                    visualize=True, multichannel=True)
print(hog_image.max())
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(img, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 50))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()
# Out:
# (800, 800, 3)
# 104.63444519042969
